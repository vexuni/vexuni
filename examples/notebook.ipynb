# %% [markdown]
# # vexuni Notebook 示例
# 直接在 Git 仓库中浏览已有的笔记本输出。预览不会执行代码。
#
# 下面的示例展示 Python 高亮、文本、静态表格与 PNG 图表。

# %%
values = [15, 30, 45, 60, 75, 90]
print(f"样本数: {len(values)}，总和: {sum(values)}")
# Out:
# 样本数: 6，总和: 315
# 样本数: 6; 总和: 315
# 按样本顺序绘制的柱状图
